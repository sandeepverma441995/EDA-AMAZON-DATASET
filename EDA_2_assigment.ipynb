# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp

# %%
df=pd.read_csv("/content/amazon.csv")

# %%
df
# Out:
#      product_id                                       product_name  \
# 0    B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1    B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2    B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3    B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4    B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ..          ...                                                ...
# 927  B07NTKGW45  SaleOn™ Portable Storage Organizer Bag for Ear...
# 928  B08CDKQ8T6  Portronics Konnect L 1.2Mtr, Fast Charging 3A ...
# 929  B08J4PL1Z3  RPM Euro Games Laptop/PC Controller Wired for ...
# 930  B07XJWTYM2  realme Buds Wireless in Ear Bluetooth Earphone...
# 931  B09939XJX8  TVARA LCD Writing Tablet, 8.5" Inch Colorful T...
#
#                                               category discounted_price  \
# 0    Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1    Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2    Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3    Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4    Computers&Accessories|Accessories&Peripherals|...             ₹154
# ..                                                 ...              ...
# 927  Computers&Accessories|Accessories&Peripherals|...             ₹397
# 928  Computers&Accessories|Accessories&Peripherals|...             ₹154
# 929  Computers&Accessories|Accessories&Peripherals|...             ₹699
# 930  Electronics|Headphones,Earbuds&Accessories|Hea...           ₹1,679
# 931  Computers&Accessories|Accessories&Peripherals|...             ₹354
#
#     actual_price discount_percentage  rating rating_count  \
# 0         ₹1,099                 64%     4.2       24,269
# 1           ₹349                 43%     4.0       43,994
# 2         ₹1,899                 90%     3.9        7,928
# 3           ₹699                 53%     4.2       94,363
# 4           ₹399                 61%     4.2       16,905
# ..           ...                 ...     ...          ...
# 927         ₹899                 56%     4.0        3,025
# 928         ₹349                 56%     4.3        7,064
# 929       ₹1,490                 53%     4.0        5,736
# 930       ₹1,999                 16%     4.1       72,563
# 931       ₹1,500                 76%     4.0        1,026
#
#                                          about_product  \
# 0    High Compatibility : Compatible With iPhone 12...
# 1    Compatible with all Type C enabled devices, be...
# 2    【 Fast Charger& Data Sync】-With built-in safet...
# 3    The boAt Deuce USB 300 2 in 1 cable is compati...
# 4    [CHARGE & SYNC FUNCTION]- This cable comes wit...
# ..                                                 ...
# 927  Electronics accessories organizer provides exc...
# 928  MORE DURABLE- Konnect L Micro cable is unique ...
# 929  RPM Euro Games controller for Windows – 7, 8, ...
# 930  11.2 mm bass boost drivers along with the Japa...
# 931  Eye Protection and Fantastic：The LCD writing t...
#
#                                                user_id  \
# 0    AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1    AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2    AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3    AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4    AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
# ..                                                 ...
# 927  AGKYLNZN5SOR4LZAYWRHAAJY6JQQ,AF3KBDP4KUQBIEPOH...
# 928  AFDCSF36NJYXASQOJCQWFQTN7SDQ,AGHRDOQP7F74DK6KE...
# 929  AGUTG6MZYET7MPUMPQXFLSNBEVUQ,AFN53ZMEK5W2MWJW6...
# 930  AEHC7ITQUJKLOGQJCAA6Q7V63EVQ,AGCW5OYJJFDRSHITP...
# 931  AGKT6MY3UZFPKSYVU5V7IOKJKMMA,AEMPOEDWHUSVZ4K5B...
#
#                                              user_name  \
# 0    Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1    ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2    Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3    Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4    rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
# ..                                                 ...
# 927  Amazon Customer,Santos,CVN,anonymous,Sacchidan...
# 928  Arun S.,Jeevan Prasad,mitesh,Tasmai Agrawal,Pa...
# 929  Rajesh sharma,Akhil Sondhi,Varun Rao,Samrat,Sh...
# 930  Tech boy,Deepak,8445025922,Ashok Alkari,Amazon...
# 931  Kanta Khaksa,SKK,Subramanian K N,Sandeep Reddy...
#
#                                              review_id  \
# 0    R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1    RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 2    R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# 3    R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1...
# 4    R1BP4L2HH9TFUP,R16PVJEXKV6QZS,R2UPDB81N66T4P,R...
# ..                                                 ...
# 927  R3D7XJFJ5YMCGX,R1XFCHMC5NZ1Y5,R1CKJ6H0A3FZI0,R...
# 928  R2ACU430AWSQ15,RZFPMZJQG4VEF,R2P7VTDLLMDOA3,R1...
# 929  R16URT7BDNOV2D,R2YWPNEAQVJ9ZA,REXSBUHVOE0WE,R2...
# 930  R1AKJKNRBIBCV4,R2ZG9F0E80XAWQ,R39LC2YR7L3N4E,R...
# 931  R374DNITJO308B,R39OSBCH26FDGW,RFTP6BKBX70WI,R1...
#
#                                           review_title  \
# 0    Satisfied,Charging is really fast,Value for mo...
# 1    A Good Braided Cable for Your Type C Device,Go...
# 2    Good speed for earlier versions,Good Product,W...
# 3    Good product,Good one,Nice,Really nice product...
# 4    As good as original,Decent,Good one for second...
# ..                                                 ...
# 927  Good at this price,Good product to organize yo...
# 928  It's working,It's gud 😳,Cable quality is good....
# 929  Overall it's good. But some keys are hard to p...
# 930  Original review 👍realme buds🎧,Please Read The ...
# 931  A good buy!,Good item fun to play , Brightness...
#
#                                         review_content  \
# 0    Looks durable Charging is fine tooNo complains...
# 1    I ordered this cable to connect my phone to An...
# 2    Not quite durable and sturdy,https://m.media-a...
# 3    Good product,long wire,Charges good,Nice,I bou...
# 4    Bought this instead of original apple, does th...
# ..                                                 ...
# 927  The product doesn't feel premium. I would say ...
# 928  Working fine,very good this data cable,Perform...
# 929  Some keys could be better but in this budget i...
# 930  (Realme Buds Wireless design and  specificatio...
# 931  A good distraction to keep kids away from devi...
#
#                                               img_link  \
# 0    https://m.media-amazon.com/images/W/WEBP_40237...
# 1    https://m.media-amazon.com/images/W/WEBP_40237...
# 2    https://m.media-amazon.com/images/W/WEBP_40237...
# 3    https://m.media-amazon.com/images/I/41V5FtEWPk...
# 4    https://m.media-amazon.com/images/W/WEBP_40237...
# ..                                                 ...
# 927  https://m.media-amazon.com/images/W/WEBP_40237...
# 928  https://m.media-amazon.com/images/I/31pQZsxPR4...
# 929  https://m.media-amazon.com/images/W/WEBP_40237...
# 930  https://m.media-amazon.com/images/I/41ZCYvl4no...
# 931  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                           product_link
# 0    https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1    https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2    https://www.amazon.in/Sounce-iPhone-Charging-C...
# 3    https://www.amazon.in/Deuce-300-Resistant-Tang...
# 4    https://www.amazon.in/Portronics-Konnect-POR-1...
# ..                                                 ...
# 927  https://www.amazon.in/SaleOnTM-Portable-Organi...
# 928  https://www.amazon.in/Portronics-Konnect-POR-1...
# 929  https://www.amazon.in/RPM-Euro-Games-Controlle...
# 930  https://www.amazon.in/realme-RMA108-Realme-Bud...
# 931  https://www.amazon.in/TVARA-Colorful-Erasable-...
#
# [932 rows x 16 columns]

# %%
pd.set_option('display.max_columns',None)

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# 1         ₹349                 43%    4.0       43,994
# 2       ₹1,899                 90%    3.9        7,928
# 3         ₹699                 53%    4.2       94,363
# 4         ₹399                 61%    4.2       16,905
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# 2  【 Fast Charger& Data Sync】-With built-in safet...
# 3  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                              user_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3  Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4  rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 2  R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# 3  R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1...
# 4  R1BP4L2HH9TFUP,R16PVJEXKV6QZS,R2UPDB81N66T4P,R...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  A Good Braided Cable for Your Type C Device,Go...
# 2  Good speed for earlier versions,Good Product,W...
# 3  Good product,Good one,Nice,Really nice product...
# 4  As good as original,Decent,Good one for second...
#
#                                       review_content  \
# 0  Looks durable Charging is fine tooNo complains...
# 1  I ordered this cable to connect my phone to An...
# 2  Not quite durable and sturdy,https://m.media-a...
# 3  Good product,long wire,Charges good,Nice,I bou...
# 4  Bought this instead of original apple, does th...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  https://m.media-amazon.com/images/W/WEBP_40237...
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
# 3  https://m.media-amazon.com/images/I/41V5FtEWPk...
# 4  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2  https://www.amazon.in/Sounce-iPhone-Charging-C...
# 3  https://www.amazon.in/Deuce-300-Resistant-Tang...
# 4  https://www.amazon.in/Portronics-Konnect-POR-1...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 932 entries, 0 to 931
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           932 non-null    object
#  1   product_name         932 non-null    object
#  2   category             932 non-null    object
#  3   discounted_price     932 non-null    object
#  4   actual_price         932 non-null    object
#  5   discount_percentage  932 non-null    object
#  6   rating               932 non-null    float64
#  7   rating_count         930 non-null    object
#  8   about_product        932 non-null    object
#  9   user_id              932 non-null    object
#  10  user_name            932 non-null    object
#  11  review_id            932 non-null    object
#  12  review_title         932 non-null    object
#  13  review_content       932 non-null    object
#  14  img_link             932 non-null    object
#  15  product_link         932 non-null    object
# dtypes: float64(1), object(15)
# memory usage: 116.6+ KB

# %%
#clean the data first

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
# Changing the data type of discounted price and actual price

# %%
df['discounted_price']=df['discounted_price'].str.replace("₹",'')
df['discounted_price']=df['discounted_price'].str.replace("",'')
df['discounted_price']=df['discounted_price'].str.replace(",",'')

# %%
df['discounted_price']
# Out:
# 0       399
# 1       199
# 2       199
# 3       329
# 4       154
#        ...
# 927     397
# 928     154
# 929     699
# 930    1679
# 931     354
# Name: discounted_price, Length: 932, dtype: object

# %%
df['discounted_price'] = df['discounted_price'].astype('float64')

# %%
df['actual_price']=df['actual_price'].str.replace(",",'')
df['actual_price']=df['actual_price'].str.replace("₹",'')
df['actual_price']=df['actual_price'].str.replace("",'')
df['actual_price']=df['actual_price'].astype('float64')

# %%
df['discount_percentage'] = df['discount_percentage'].replace('%','').astype('float64')

# %%
df['discount_percentage'].dtype
# Out:
# dtype('float64')

# %%
df['discount_percentage']=df['discount_percentage']/100

# %%
#finding unusual string in rating count
df['rating'].value_counts()
# Out:
# 4.3    170
# 4.2    150
# 4.1    146
# 4.0    119
# 4.4     87
# 3.9     71
# 4.5     51
# 3.8     46
# 3.7     25
# 3.5     19
# 3.6     14
# 3.3     11
# 4.6      7
# 3.4      6
# 5.0      3
# 3.0      3
# 4.7      2
# 3.2      1
# 2.8      1
# Name: rating, dtype: int64

# %%
df['rating_count']=df['rating_count'].str.replace(",",'').astype('float64')

# %%
#missing value
df.isnull().sum().sort_values(ascending=True)
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# rating_count           2
# dtype: int64

# %%
df[df['rating_count'].isnull()].head(5)
# Out:
#      product_id                                       product_name  \
# 282  B0B94JPY2N  Amazon Brand - Solimo 65W Fast Charging Braide...
# 324  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
#
#                                               category  discounted_price  \
# 282  Computers&Accessories|Accessories&Peripherals|...             199.0
# 324  Computers&Accessories|Accessories&Peripherals|...             249.0
#
#      actual_price  discount_percentage  rating  rating_count  \
# 282         999.0                 0.80     3.0           NaN
# 324         999.0                 0.75     5.0           NaN
#
#                                          about_product  \
# 282  USB C to C Cable: This cable has type C connec...
# 324  💎[The Fastest Charge] - This iPhone USB C cabl...
#
#                           user_id    user_name      review_id  \
# 282  AE7CFHY23VAJT2FI4NZKKP6GS2UQ       Pranav   RUB7U91HVZ30
# 324  AGJC5O5H5BBXWUV7WRIEIOOR3TVQ  Abdul Gafur  RQXD5SAMMPC6L
#
#                                      review_title  \
# 282  The cable works but is not 65W as advertised
# 324                               Awesome Product
#
#                                         review_content  \
# 282  I have a pd supported car charger and I bought...
# 324  Quick delivery.Awesome ProductPacking was good...
#
#                                               img_link  \
# 282  https://m.media-amazon.com/images/W/WEBP_40237...
# 324  https://m.media-amazon.com/images/I/31-q0xhaTA...
#
#                                           product_link
# 282  https://www.amazon.in/Amazon-Brand-Charging-Su...
# 324  https://www.amazon.in/REDTECH-Lightning-Certif...

# %%
df['rating_count']=df.rating_count.fillna(value=df['rating_count'].median())

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
#find any dublicate
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
any_dublicate=df.duplicated(subset=['product_id', 'product_name', 'category', 'discounted_price',
       'actual_price', 'discount_percentage', 'rating', 'rating_count',
       'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
       'review_content', 'img_link', 'product_link']).any()

# %%
any_dublicate
# Out:
# False

# %%
#data c;eaning and data prepartion is over now data visiluation

# %%
#What is the average rating for each product category?
average_rating=df.groupby("category")["rating"].mean().reset_index()

# %%
average_rating
# Out:
#                                               category  rating
# 0    Computers&Accessories|Accessories&Peripherals|...    4.15
# 1    Computers&Accessories|Accessories&Peripherals|...    3.50
# 2    Computers&Accessories|Accessories&Peripherals|...    3.60
# 3    Computers&Accessories|Accessories&Peripherals|...    4.00
# 4    Computers&Accessories|Accessories&Peripherals|...    4.20
# ..                                                 ...     ...
# 121  OfficeProducts|OfficePaperProducts|Paper|Stati...    4.30
# 122  OfficeProducts|OfficePaperProducts|Paper|Stati...    4.25
# 123  OfficeProducts|OfficePaperProducts|Paper|Stati...    4.30
# 124  OfficeProducts|OfficePaperProducts|Paper|Stati...    4.05
# 125  Toys&Games|Arts&Crafts|Drawing&PaintingSupplie...    4.30
#
# [126 rows x 2 columns]

# %%
#What are the top rating_count products by category?¶
top_ratingcount=df.groupby("category")["rating_count"].max().sort_values(ascending=False)

# %%
top_ratingcount
# Out:
# category
# Electronics|HomeTheater,TV&Video|Accessories|Cables|HDMICables               426973.0
# Electronics|Headphones,Earbuds&Accessories|Headphones|In-Ear                 363713.0
# Electronics|Mobiles&Accessories|Smartphones&BasicMobiles|Smartphones         313836.0
# Computers&Accessories|ExternalDevices&DataStorage|PenDrives                  253105.0
# Electronics|Accessories|MemoryCards|MicroSD                                  205052.0
#                                                                                ...
# OfficeProducts|OfficePaperProducts|Paper|Copy&PrintingPaper|ColouredPaper       388.0
# Computers&Accessories|Components|InternalHardDrives                             362.0
# Electronics|Mobiles&Accessories|MobileAccessories|Décor|PhoneCharms             305.0
# Electronics|HomeAudio|Speakers|TowerSpeakers                                    282.0
# Electronics|HomeAudio|MediaStreamingDevices|StreamingClients                    224.0
# Name: rating_count, Length: 126, dtype: float64

# %%
#Q3: What is the distribution of discounted prices vs. actual prices?
df['discounted_price'].hist(label='Discounted_price')
df['actual_price'].hist(label='actual_price')
df['discount_percentage']=(df['actual_price']-df['discounted_price'])/df['actual_price']*100
df['discount_percentage'].describe()
df['discount_percentage'].hist(label='Discount_percentage')
# Out:
# <Axes: >

# %%
#Q4: How does the average discount percentage vary across categories
avg_dis_per=df.groupby("category")["discount_percentage"].mean()
print(avg_dis_per)
sns.barplot(x=avg_dis_per.index,y=avg_dis_per.values)
plt.xlabel("category")
plt.ylabel("avgerge percent discount")
plt.show()
# Out:
# category
# Computers&Accessories|Accessories&Peripherals|Adapters|USBtoUSBAdapters                                                   78.387733
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCHeadsets                                           35.035035
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCMicrophones                                        56.335120
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCSpeakers                                           43.362241
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|Webcams&VoIPEquipment|Webcams                        44.443918
#                                                                                                                             ...
# OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|BottledInk                   5.000000
# OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|GelInkRollerballPens         0.000000
# OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|RetractableBallpointPens    17.619048
# OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|StickBallpointPens           7.500000
# Toys&Games|Arts&Crafts|Drawing&PaintingSupplies|ColouringPens&Markers                                                      0.000000
# Name: discount_percentage, Length: 126, dtype: float64

# %% [markdown]
# t.

# %%
#Q5: What are the most popular product name?¶

# %%
product_count=df['product_name'].value_counts().sort_values(ascending=False).head(10)

# %%
product_count
# Out:
# Fire-Boltt Ninja Call Pro Plus 1.83" Smart Watch with Bluetooth Calling, AI Voice Assistance, 100 Sports Modes IP67 Rating, 240*280 Pixel High Resolution                                            5
# Fire-Boltt Phoenix Smart Watch with Bluetooth Calling 1.3",120+ Sports Modes, 240*240 PX High Res with SpO2, Heart Rate Monitoring & IP67 Rating                                                     4
# Ambrane Unbreakable 60W / 3A Fast Charging 1.5m Braided Type C Cable for Smartphones, Tablets, Laptops & other Type C devices, PD Technology, 480Mbps Data Sync, Quick Charge 3.0 (RCT15A, Black)    3
# boAt Micro USB 55 Tangle-free, Sturdy Micro USB Cable with 3A Fast Charging & 480mbps Data Transmission (Black)                                                                                      3
# MI Usb Type-C Cable Smartphone (Black)                                                                                                                                                               3
# pTron Solero TB301 3A Type-C Data and Fast Charging Cable, Made in India, 480Mbps Data Sync, Strong and Durable 1.5-Meter Nylon Braided USB Cable for Type-C Devices for Charging Adapter (Black)    3
# Portronics Konnect L 1.2M Fast Charging 3A 8 Pin USB Cable with Charge & Sync Function for iPhone, iPad (Grey)                                                                                       3
# Sounce Fast Phone Charging Cable & Data Sync USB Cable Compatible for iPhone 13, 12,11, X, 8, 7, 6, 5, iPad Air, Pro, Mini & iOS Devices                                                             3
# Portronics Konnect L POR-1081 Fast Charging 3A Type-C Cable 1.2Meter with Charge & Sync Function for All Type-C Devices (Grey)                                                                       3
# Portronics Konnect CL 20W POR-1067 Type-C to 8 Pin USB 1.2M Cable with Power Delivery & 3A Quick Charge Support, Nylon Braided for All Type-C and 8 Pin Devices, Green                               3
# Name: product_name, dtype: int64

# %%
#Q6: What are the most popular product keywords?¶
def extract_keywords(product_name):
  """Extracts keywords from a product name, handling potential numbers."""
  if isinstance(product_name, str):  # Check if it's a string
    keywords = product_name.lower().split()  # Split into words and lowercase
    keywords = [word for word in keywords if word.isalpha()]  # Remove non-alphabetical characters
  else:
    keywords = []  # Handle non-string values (e.g., integers) by returning an empty list
  return keywords

# Apply the function to extract keywords
df["keywords"] = df["product_name"].apply(extract_keywords)

# Flatten the list of keywords
all_keywords = [keyword for keywords in df["keywords"] for keyword in keywords]

# Count keyword occurrences
keyword_counts = pd.Series(all_keywords).value_counts()

# Display the top 10 most popular keywords
print(keyword_counts.head(10))
# Out:
# with        496
# for         444
# usb         330
# cable       298
# charging    206
# and         203
# fast        192
# to          169
# c           166
# smart       156
# dtype: int64

# %%
#Q7: What are the most popular product reviews?¶
from textblob import TextBlob
df[["product_id","user_id","review_content"]]
df["sentiment"]=df["review_content"].apply(lambda text:TextBlob(text).sentiment.polarity)
df_sorted=df.sort_values(by="sentiment",ascending=True)
top_review=df_sorted.head(10)
print(top_review)
# Out:
#      product_id                                       product_name  \
# 155  B09XJ1LM7R  7SEVEN® Compatible for Tata Sky Remote Origina...
# 145  B00RFWNJMC  Airtel DigitalTV DTH Remote SD/HD/HD Recording...
# 152  B08PV1X771  Samsung 80 cm (32 inches) Wondertainment Serie...
# 22   B09F6S8BT6  Samsung 80 cm (32 Inches) Wondertainment Serie...
# 723  B09F6S8BT6  Samsung 80 cm (32 Inches) Wondertainment Serie...
# 738  B08MZQBFLN  Callas Multipurpose Foldable Laptop Table with...
# 275  B09LV13JFB  LOHAYA Voice Assistant Remote Compatible for A...
# 681  B08CF4SCNP  Quantum QHM-7406 Full-Sized Keyboard with (₹) ...
# 919  B00LZPQVMK  Parker Vector Standard Chrome Trim Ball Pen (I...
# 234  B0B65P827P  Zebronics CU3100V Fast charging Type C cable w...
#
#                                               category  discounted_price  \
# 155  Electronics|HomeTheater,TV&Video|Accessories|R...            399.00
# 145  Electronics|HomeTheater,TV&Video|Accessories|R...            195.00
# 152  Electronics|HomeTheater,TV&Video|Televisions|S...          15490.00
# 22   Electronics|HomeTheater,TV&Video|Televisions|S...          13490.00
# 723  Electronics|HomeTheater,TV&Video|Televisions|S...          13490.00
# 738  Computers&Accessories|Accessories&Peripherals|...            849.00
# 275  Electronics|HomeTheater,TV&Video|Accessories|R...            399.00
# 681  Computers&Accessories|Accessories&Peripherals|...            299.00
# 919  OfficeProducts|OfficePaperProducts|Paper|Stati...            272.00
# 234  Computers&Accessories|Accessories&Peripherals|...            128.31
#
#      actual_price  discount_percentage  rating  rating_count  \
# 155         799.0            50.062578     4.3          12.0
# 145         499.0            60.921844     3.7        1383.0
# 152       20900.0            25.885167     4.3       16299.0
# 22        22900.0            41.091703     4.3       16299.0
# 723       22900.0            41.091703     4.3       16299.0
# 738        4999.0            83.016603     4.0       20457.0
# 275         999.0            60.060060     3.3          23.0
# 681         599.0            50.083472     3.8        3066.0
# 919         320.0            15.000000     4.0        3686.0
# 234         549.0            76.628415     3.9          61.0
#
#                                          about_product  \
# 155  [Compatible] All model of dth SD / HD / HD+ Pl...
# 145                Compatible with SD and HD Recording
# 152  Resolution: HD Ready (1366x768) | Refresh Rate...
# 22   Resolution: HD Ready (1366x768) | Refresh Rate...
# 723  Resolution: HD Ready (1366x768) | Refresh Rate...
# 738  【WATCH, PLAY, STUDY - WITHOUT LEAVING THE BED!...
# 275  100% Best Quality Plastic Body and Soft Silico...
# 681  PLUG & PLAY CONNECT: Easy to connect with your...
# 919  A solid plastic body of the glossy black desig...
# 234  Fast charging support for various smart phones...
#
#                                                user_id  \
# 155                       AE242TR3GQ6TYC6W4SJ5UYYKBTYQ
# 145  AGD2H2SMDLQK62MH7BFWQ2INBP2A,AELIUKITTHS3MSGTS...
# 152  AHEVO4Q5NM4YXMG2HDDXC5XMBGRQ,AFZPH7ZAWX5VDY3HO...
# 22   AHEVO4Q5NM4YXMG2HDDXC5XMBGRQ,AFZPH7ZAWX5VDY3HO...
# 723  AHEVO4Q5NM4YXMG2HDDXC5XMBGRQ,AFZPH7ZAWX5VDY3HO...
# 738  AHB4AEOCLEVH2JSTXPU737KTXS4Q,AHXC62FGJRYSCJEBZ...
# 275  AERUC72DWRPOM2EHX3YBTBPKYV7A,AHMH6RNLYI2G65HY7...
# 681  AEZRH2UWC5CQXUVLFUEAYAPXDFGQ,AEVMIO4NTG5PTXCPY...
# 919  AE3S2ZAEMH765KUJ57DR6HBZBB3Q,AHSIVUNTJMI5S5AJG...
# 234  AFQGGBH7UOPRRK6A4FS6UAHBBR6Q,AHUVPTZIP7GEDM62E...
#
#                                              user_name  \
# 155                                        anurag jain
# 145  ABHAY SINGH,kapil,Amazon Customer,M.V.SUBBA RA...
# 152  Rahman Ali,MARIYA DASS,Md Aftab,roshan s.,Moha...
# 22   Rahman Ali,MARIYA DASS,Md Aftab,roshan s.,Moha...
# 723  Rahman Ali,MARIYA DASS,Md Aftab,roshan s.,Moha...
# 738  Jasmeen,Santam paul,Deepak,Perabathula Sriniva...
# 275  Amazon Customer,Amazon Customer,Akul,Akash Yad...
# 681  Hariom Mishra,Vikas yadav,Santosh Chauhan,SIDD...
# 919  Fardeen mujawar,Pavan,Danny,Siddhartha Pratap,...
# 234  samarth shukla,Sanjeev Kumar,Gigi,G RAJAN,Srin...
#
#                                              review_id  \
# 155                                     R38OAD16RVS9D4
# 145  R2RV2M8NMHN3R6,R39R9NAW42YGZ7,R1P3SC4CEA50V1,R...
# 152  R1SN0D4DFBKAZI,R1SX5L77L2CD6V,R1NAZ6M4QBUJMK,R...
# 22   R1SN0D4DFBKAZI,R1SX5L77L2CD6V,R1NAZ6M4QBUJMK,R...
# 723  R1SN0D4DFBKAZI,R1SX5L77L2CD6V,R1NAZ6M4QBUJMK,R...
# 738  R1GJXMBEY4O49A,R2RJ4QKYQ0VWIL,R2C6XBMID12B8B,R...
# 275  R1P2VLNHZAHSCU,R28B2GC0X0RMKW,RQ2S0N0NGDQVY,R1...
# 681  R2L4XIZ518GOR1,RPVZZE1EB5RNS,RF4O6NIV5JCCW,R34...
# 919  RD6OIJUG0R241,R3EUJ7A6LG8X7V,R1DWGT4USEVGYK,R1...
# 234  R2NO4JULWOQQ5N,R1RJ8AHYBK38PD,R3PU1G9HCGIUHP,R...
#
#                                           review_title  \
# 155                                         do not buy
# 145  Good product,Not bad,WORKING WITH Airtel DTH,G...
# 152  Good,Sound is very low another brand comparing...
# 22   Good,Sound is very low another brand comparing...
# 723  Good,Sound is very low another brand comparing...
# 738  Nice but price should be reduced,WORTH FOR MON...
# 275  When I placed the order I was in doubt whether...
# 681  Comfortable keys and smooth typing,Good at thi...
# 919  Ok,Like all other ball pens,Regular pen over p...
# 234  Terrible,Charging status,Good quality,good cha...
#
#                                         review_content  \
# 155  tv on off not working, so difficult to battery...
# 145  Value of money,Usually  gd,Good Product,Good,Q...
# 152  Overall good.,TV picture ok smart betterSound ...
# 22   Overall good.,TV picture ok smart betterSound ...
# 723  Overall good.,TV picture ok smart betterSound ...
# 738  Price is high,https://m.media-amazon.com/image...
# 275  Ok,Very disappointedRange is not good it doesn...
# 681  Comfortable keys and smooth typing,Good,Averag...
# 919  Can buy but only when price is less,It's not t...
# 234  After 1-2 months , it has become worse and my ...
#
#                                               img_link  \
# 155  https://m.media-amazon.com/images/W/WEBP_40237...
# 145  https://m.media-amazon.com/images/W/WEBP_40237...
# 152  https://m.media-amazon.com/images/W/WEBP_40237...
# 22   https://m.media-amazon.com/images/W/WEBP_40237...
# 723  https://m.media-amazon.com/images/I/51q3+E64az...
# 738  https://m.media-amazon.com/images/W/WEBP_40237...
# 275  https://m.media-amazon.com/images/W/WEBP_40237...
# 681  https://m.media-amazon.com/images/I/41y181oD7Z...
# 919  https://m.media-amazon.com/images/W/WEBP_40237...
# 234  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                           product_link  \
# 155  https://www.amazon.in/7SEVEN%C2%AE-Compatible-...
# 145  https://www.amazon.in/OXYURA-Airtel-Digital-Re...
# 152  https://www.amazon.in/Samsung-inches-Wondertai...
# 22   https://www.amazon.in/Samsung-Inches-Wondertai...
# 723  https://www.amazon.in/Samsung-Inches-Wondertai...
# 738  https://www.amazon.in/Callas-Multipurpose-Brea...
# 275  https://www.amazon.in/LOHAYA-Assistant-Compati...
# 681  https://www.amazon.in/Quantum-QHM-7406-Spill-R...
# 919  https://www.amazon.in/Parker-Vector-Standard-B...
# 234  https://www.amazon.in/Zebronics-charging-capac...
#
#                                               keywords  sentiment
# 155  [compatible, for, tata, sky, remote, original,...  -0.600000
# 145  [airtel, digitaltv, dth, remote, recording, co...  -0.179762
# 152  [samsung, cm, wondertainment, series, hd, read...  -0.172245
# 22   [samsung, cm, wondertainment, series, hd, read...  -0.172245
# 723  [samsung, cm, wondertainment, series, hd, read...  -0.172245
# 738  [callas, multipurpose, foldable, laptop, table...  -0.118750
# 275  [lohaya, voice, assistant, remote, compatible,...  -0.106250
# 681  [quantum, keyboard, with, rupee, hotkeys, and,...  -0.086458
# 919  [parker, vector, standard, chrome, trim, ball,...  -0.055952
# 234  [zebronics, fast, charging, type, c, cable, wi...  -0.027083

# %%
#Q8: What is the correlation between discounted_price and rating?
correlation_cofficent=df["discounted_price"].corr(df['rating'])
print(correlation_cofficent)
# Out:
# 0.10848357702261455

# %%
#Q9: What are the Top 5 categories based with highest ratings?
average_ratings=df.groupby("category")['rating'].mean().reset_index()
average_ratings=average_ratings.sort_values(by='rating',ascending=False)
print(average_ratings)
# Out:
#                                               category  rating
# 71   Electronics|HomeAudio|MediaStreamingDevices|St...     4.5
# 53    Electronics|Cameras&Photography|Accessories|Film     4.5
# 35             Computers&Accessories|Components|Memory     4.5
# 25   Computers&Accessories|Accessories&Peripherals|...     4.5
# 115  OfficeProducts|OfficeElectronics|Calculators|B...     4.5
# ..                                                 ...     ...
# 1    Computers&Accessories|Accessories&Peripherals|...     3.5
# 78   Electronics|HomeTheater,TV&Video|Accessories|3...     3.5
# 47   Computers&Accessories|Printers,Inks&Accessorie...     3.5
# 48   Computers&Accessories|Printers,Inks&Accessorie...     3.4
# 12   Computers&Accessories|Accessories&Peripherals|...     3.4
#
# [126 rows x 2 columns]
